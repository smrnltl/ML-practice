# %% [markdown]
# #

# %% [markdown]
# Importing data

# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Reading Data in Pandas

# %%
# Reading Data in Pandas

#read headers
#print(df.columns)

## read columns
#print(df['Name'].head(5)) #selcts first 5 rows
#print(df['Name'][0:5]) #selects first 5 rows
#print(df[['Name', 'Type 1', 'HP']].head(5)) #selcts first 5 rows of different columns

# read each row
#print(df.iloc[1]) # first row, iloc is used for locating index in the dataframe
#print(df.iloc[1:4]) # multiple rows

#reading each row with iterations
#for index, row in df.iterrows():
    #print(index, row) # print all columns for each row
#    print(index, row['Name']) # print index and name of each row
#df.loc[df['Type 1'] == "Fire"]


## read a specific location (R,C)
#print(df.iloc[2,1])

# %% [markdown]
# Sorting/Describing data

# %%
#df.describe() 

df.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Making changes to the data

# %%
#df.head(5)
#add a total column
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Generation'] + df['Legendary']

#drop total column
#df = df.drop(columns=['Total'])

#add new column 'Total' in another way
df['Total'] = df.iloc[:, 4:10].sum(axis=1) # gets all the cols and appends the sum of 4:9 in horizontal axis, 
                                        # here 4:10 is written instead of 4:9 because 10th column is not included
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Saving our data (Exporting into desired format)

# %%
#df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

#df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# Filtering Data

# %%
#df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

#df.loc[~df['Name'].str.contains('Mega')]

import re #regular expressions

df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex = True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %% [markdown]
# Conditional Changes

# %%
df = pd.read_csv('modified.csv')

#df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
#df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = 'TEST'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# Aggregate Statistics (Groupby)

# %%
df = pd.read_csv('modified.csv')

#df.groupby(['Type 1']).mean(numeric_only=True).sort_values('Attack', ascending=False)

#df.groupby(['Type 1']).sum(numeric_only=True)

df['count']=1

df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# Working with large amounts of data

# %%
#for df in pd.read_csv('modified.csv', chunksize=100):
#    print("CHUNK DF")
#    print(df)

new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])

new_df
# Out:
#          # Name Type 1 Type 2 Total HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1    1    NaN      0     1  1      1       1       1       1     1
# Grass    4    4    NaN      4     4  4      4       4       4       4     4
# Fire     4    4    NaN      3     4  4      4       4       4       4     4
# Water    1    1    NaN      0     1  1      1       1       1       1     1
# Bug      2    2    NaN      0     2  2      2       2       2       2     2
# ...     ..  ...    ...    ...   ... ..    ...     ...     ...     ...   ...
# Fairy    1    1    NaN      0     1  1      1       1       1       1     1
# Flying   2    2    NaN      2     2  2      2       2       2       2     2
# Fire     1    1    NaN      1     1  1      1       1       1       1     1
# Psychic  2    2    NaN      2     2  2      2       2       2       2     2
# Rock     2    2    NaN      2     2  2      2       2       2       2     2
#
#         Generation Legendary
# ...
